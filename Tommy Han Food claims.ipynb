# %% [markdown]
# ## Task 1

# %% [markdown]
# The original data is 8 columns and 2000 rows. Firstly I checked every 8 columns and check if they correspond to the dataset description.
#
# Time_to_close: no missing value.
# Claim_amount: no missing value. data type changed from general to number in excel. currency removed.
# amount_paid: 36 missing values sighted. missing values were replaced with median amount_paid 20105.7.
# Location: no missing value. There were 4 locations as expected.
# individual_on_claim: no missing value. Minimum 1 person as expected.
# Linked_cases: 26 missing value. NA value replaced with FALSE.
# Causes: 3 causes as expected. no missing value. Causes previously treated as separate categories due to differences in capitalization, but they are now combined (meat and Meat. vegetable and VEGETABLES )

# %% [markdown]
# ## Task 2

# %% [markdown]
# Create a visualisation that shows the number of claims in each location. Use the visualisation to
# a. State which category of the variable location has the most observations
# b. Explain whether the observations are balanced across categories of the variable location
#
#
# ![numbers of claim.png](attachment:4e96f04a-aa01-436f-979b-ba0c6b74ba72.png)
#
#
# Based on the bar chart provided, it is evident that Recife had the highest number of reported food poisoning cases, with a total of 885 incidents. It is notable that meat was the primary cause of food poisoning in each location, with unknown causes being the second most common, and vegetables being the least common cause. It is arguable that the observations are balanced across categories given that food poisoning cases attributed to meat accounted for over 50% of the total cases in each location.

# %% [markdown]
# ## Task 3

# %% [markdown]
# Describe the distribution of time to close for all claims. Your answer must include a visualisation that shows the distribution.
#
# ![time to close distribution.png](attachment:8ee71584-c5b4-4b33-8be1-10328cab48a1.png)
#
# Based on the bar chart provided, it demonstrates mild right-skewed distribution. the most common time to close is 176 days and there are a few outliers over 400 days. In order to improve the performance, it is best to avoid outliers such as claims that takes more than 400 days and set a target as under 200 days.

# %% [markdown]
# ## Task 4

# %% [markdown]
# Describe the relationship between time to close and location. Your answer must include a visualisation to demonstrate the relationship.
#
# ![location.png](attachment:21f97391-ccf5-4d88-a8e7-67ca32763f38.png)
#
# ![box plot.png](attachment:56989bf2-b2dc-4274-9718-f4d1cdcde0f6.png)
#
# According to charts above, there are no significant differences when it comes to the average time to close by location. the mean values in all locations sit at around 185 days. If you look at box plot, time to close values are fairly balanced while some outliers are observed in Fortaleza and Sao Luis. It is believed that avoiding those outliers would significantly lower the overall time to close.
